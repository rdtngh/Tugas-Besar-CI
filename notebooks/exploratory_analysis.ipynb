# %% [markdown]
# # Exploratory Analysis
#
# Notebook ini berisi analisis awal dataset StressLevelDataset.csv untuk memahami fitur, distribusi target, dan korelasi.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/StressLevelDataset.csv')
df.head()
